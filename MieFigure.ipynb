# %% [markdown]
# # Mie Scattering

# %% [markdown]
# Defining
# \begin{align}
#     x &= k_1R\\
#     Mx &= \frac{n_2}{n_1}k_1a = k_2R.
# \end{align}
# $R$ being the sphere radius, $n_1$ the outside refraction index and $n_2$ the inside.
# \begin{align}
#     \Psi_n(\rho) &= \rho j_n(\rho)\\
#     \zeta(\rho) &= \rho h_n^{(1)}(\rho),
# \end{align}
# where
# \begin{equation}
#     j_n(r) = \sqrt{\frac{\pi}{2r}}J_{n+1/2}(r),
# \end{equation}
#
# \begin{equation}
#     y_n(r) = \sqrt{\frac{\pi}{2r}}Y_{n+1/2}(r),
# \end{equation}
#
# \begin{align}
#     h_n^{(1)}(r) &= j_n(r)+iy_n(r)\\
#     h_n^{(2)}(r) &= j_n(r)-iy_n(r).
# \end{align}
#
#
# Giving us the coefficients
# \begin{align}
#     a_{nm} &= \frac{M\Psi_n(Mx)\Psi_n^{\prime}(x)-\Psi_n^{\prime}(Mx)\Psi_n(x)}{\Psi_n^{\prime}(Mx)\zeta_n(x)-M\Psi_n(Mx)\zeta_n^{\prime}(x)}G_{nm}^{MT}\\
#     b_{nm} &=\frac{M\Psi_n^{\prime}(Mx)\Psi_n(x)-\Psi_n(Mx)\Psi_n^{\prime}(x)}{\Psi_n(Mx)\zeta_n^{\prime}(x)-M\Psi_n^{\prime}(Mx)\zeta_n(x)}G_{nm}^{ET}
#     \end{align}

# %% [markdown]
# Now that we know how the expected solution looks, we can introduce a vector function called the spherical harmonic vector, where by defining $\vec{L} = i\vec{r}\times \vec{\nabla} $ is
# \begin{equation}
#     \vec{X}_{nm}(\theta,\phi) = \frac{1}{\sqrt{n(n+1)}}\vec{L}Y_{nm}(\theta,\phi),
# \end{equation}
# where
# \begin{equation}
#     Y_{nm} = \sqrt{ \frac{2n+1}{4\pi}\frac{(n-m)!}{(n+m)!}}P_n^m(cos\theta)e^{im\phi}.
# \end{equation}
# We can represent the Constants of the incident fields as
#
# \begin{align}
#     G_{nm}^{TE}j_n(kr) &= \frac{-k}{E_0\sqrt{n(n+1)}}\int Y_{nm}^*(\theta,\phi)\vec{r}\cdot\vec{E}d\Omega\\
#     G_{nm}^{TM}j_n(kr) &= \frac{k}{H_0\sqrt{n(n+1)}}\int Y_{nm}^*(\theta,\phi)\vec{r}\cdot\vec{H}d\Omega.
# \end{align}
#
# Representing the fields using the spherical solution of the wave equation, we can express the incident field using constants $G_{nm}^{TE} = A_{nm}$ and $G_{nm}^{TM}=B_{nm}$ for the transversal electric and transversal magnetic components, respectively.
#
# \begin{align}
#     \vec{E}_{\text{inc}} &= E_0 \sum_{n,m}( \frac{i}{k_1}G_{nm}^{TM}\nabla \times (j_n(k_1r)\vec{X}_{nm}(\theta,\phi)
#     \\&  + G_{nm}^{TE}j_n(k_1r)\vec{X}_{nm}(\theta,\phi) )\\
#     \vec{H}_{\text{inc}} &= \frac{E_0}{Z_1}\sum_{n,m} (G_{nm}^{TM}j_n(k_1r)\vec{X}_{nm}(\theta,\phi) \\
#     & -\frac{i}{k_1} G_{nm}^{TE}\nabla \times j_n(k_1r)\vec{X}_{nm}(\theta,\phi) ).
# \end{align}
#
# Similarly, we express the field inside the sphere using the refractive index within this space, resulting in constants $c_{nm}$ and $d_{nm}$.
#
# \begin{align}
#     \vec{E}_{\text{int}} &= E_0 \sum_{n,m}( \frac{i}{k_2}c_{nm}\nabla \times (j_n(k_2 r)\vec{X}_{nm}(\theta,\phi)) \\
#     &  + d_{nm}j_n(k_2r)\vec{X}_{nm}(\theta,\phi) \\
#     \vec{H}_{\text{int}} &= \frac{E_0}{Z_2}\sum_{n,m} (c_{nm}j_n(k_2r)\vec{X}_{nm}(\theta,\phi) \\
#     &  -\frac{i}{k_2} d_{nm}\nabla \times j_n(k_2r)\vec{X}_{nm}(\theta,\phi) ).
# \end{align}
#
# The scattered field exists outside the sphere and propagates through high values of $r$. In this limit, the spherical Hankel function is used, specifically $h_n^{(1)}$, which describes functions that continue growing. The scattered fields are expressed using constants $a_{nm}$ and $b_{nm}$.
#
# \begin{align}
#     \vec{E}_{\text{sca}} &= E_0 \sum_{n,m}( \frac{i}{k_1}a_{nm}\nabla \times (h_n^{(1)}(k_1 r)\vec{X}_{nm}(\theta,\phi) \\
#     &  + b_{nm}h_n^{(1)}(k_1r)\vec{X}_{nm}(\theta,\phi) )\\
#     \vec{H}_{\text{sca}} &= \frac{E_0}{Z_1}\sum_{n,m} (a_{nm}h_n^{(1)}(k_1r)\vec{X}_{nm}(\theta,\phi) \\ &  -\frac{i}{k_1} b_{nm}\nabla \times h_n^{(1)}(k_1r)\vec{X}_{nm}(\theta,\phi) ).
# \end{align}

# %% [markdown]
# Rearanging the Scattered Field we can obtain
#
# \begin{equation}
#     \vec{E_{scat}} = E_0 \sum_{n,m}...
# \end{equation}

# %% [markdown]
# Substituting the Mie COefficients in the calculations
#
# \begin{align}
#     a_{nm} &= \frac{M\Psi_n(Mx)\Psi_n^{\prime}(x)-\Psi_n^{\prime}(Mx)\Psi_n(x)}{\Psi_n^{\prime}(Mx)\zeta_n(x)-M\Psi_n(Mx)\zeta_n^{\prime}(x)}G_{nm}^{MT}\\
#     b_{nm} &=\frac{M\Psi_n^{\prime}(Mx)\Psi_n(x)-\Psi_n(Mx)\Psi_n^{\prime}(x)}{\Psi_n(Mx)\zeta_n^{\prime}(x)-M\Psi_n^{\prime}(Mx)\zeta_n(x)}G_{nm}^{ET} ,
# \end{align}
# where $G_{n\pm 1}^{ET} = -i \sqrt{\pi (2n +1)} i^{n+1}$,
#
# $G_{n,+1}^{TM} =-\sqrt{\pi(2n +1)}i^{n+1} $ and
#
#  $G_{n,-1}^{TM} =\sqrt{\pi(2n +1)}i^{n+1} $

# %% [markdown]
# # Simulation

# %%
import numpy as np
from scipy.special import spherical_jn, spherical_yn , hankel1,lpmv
import matplotlib.pyplot as plt

# %%
def MieCoefCond2(x, n, k1):
    jn = spherical_jn(n, x)
    jn1 = spherical_jn(n+1,x)
    jn_1 = spherical_jn(n-1,x)
    
    hankeln = np.sqrt(np.pi/(2*x))*hankel1(n+1/2,x)
    hankeln1 = np.sqrt(np.pi/(2*x))*hankel1(n+1+1/2,x)
    hankeln_1 = np.sqrt(np.pi/(2*x))*hankel1(n-1+1/2,x)
    
    a = -(jn + x *1/2* (  x* (jn_1-jn1) + jn ))/(hankeln + x  *1/2* ( x*(hankeln_1-hankeln1) + hankeln))

    b = - jn/hankeln  

    
    return a, b

# Example usage
x = 1.0
n = 1
GTM = 2.0
GTE = 3.0
k1 = 0.5


a, b = MieCoefCond2(x, n, k1)
print("a:", a)
print("b:", b)
# Out:
# a: (-0.7080734182735715-0.45464871341284113j)
# b: (-0.04535128658715921-0.20807341827357145j)

# %%
def MieCoef(x, M, n):
    # Computing spherical Bessel functions for n and M*n
    j_n_x = spherical_jn(n, x)
    j_n_Mx = spherical_jn(n, M*x)

    # Computing Riccati-Bessel functions
    psi_n_x = x * j_n_x
    zeta_n_x = x * np.sqrt(np.pi/(2*x))*hankel1(n+1/2,x)

    psi_n_Mx = M * x * j_n_Mx
    zeta_n_Mx = M * x * np.sqrt(np.pi/(2*M*x))*hankel1(n+1/2,M*x)

    # Computing Riccati-Bessel function derivatives using numdifftools
    #psi_n_x_prime = nd.Derivative(lambda x: x * spherical_jn(n, x), n=1, order=1)(x)
    psi_n_x_prime = 1/2* (  x* (spherical_jn(n-1,x)-spherical_jn(n+1,x)) + spherical_jn(n,x) ) 
    
    zeta_n_x_prime = 1/2* np.sqrt(np.pi/(2*x))*(  x* (hankel1(n+1/2-1,x)-hankel1(n+1/2+1,x)) + hankel1(n+1/2,x) )

    #psi_n_Mx_prime = nd.Derivative(lambda x: M * x * spherical_jn(n, M * x), n=1, order=1)(x)
    psi_n_Mx_prime = 1/2* (  M*x* (spherical_jn(n-1,M*x)-spherical_jn(n+1,M*x)) + spherical_jn(n,M*x) ) 
    
    zeta_n_Mx_prime= 1/2* np.sqrt(np.pi/(2*M*x))*(  x* (hankel1(n+1/2-1,M*x)-hankel1(n+1/2+1,M*x)) + hankel1(n+1/2,M*x) )

    # Calculating coefficients a_n, b_n, c_n, d_n
    a_n = (M * psi_n_Mx * psi_n_x_prime - psi_n_Mx_prime * psi_n_x) / (psi_n_Mx_prime * zeta_n_x - M * psi_n_Mx * zeta_n_x_prime)
    b_n = (M * psi_n_Mx_prime * psi_n_x - psi_n_Mx * psi_n_x_prime) / (psi_n_Mx * zeta_n_x_prime - M * psi_n_Mx_prime * zeta_n_x)
    
    #c_n = (psi_n_x * zeta_n_x_prime - psi_n_x_prime * zeta_n_x) / (psi_n_Mx_prime * zeta_n_x - M * psi_n_Mx * zeta_n_x_prime)
    #d_n = (psi_n_x_prime * zeta_n_x - psi_n_x * zeta_n_x_prime) / (psi_n_Mx * zeta_n_x_prime - M * psi_n_Mx_prime * zeta_n_x)

    return a_n, b_n

# Test the function with scalar inputs
wavelength = 1
radius = 5
k = 2 * np.pi / wavelength
x_value = k * radius
print(MieCoef(x_value, 155/133, 30))
# Out:
# ((-0.5057268366161177-0.4999672022666795j), (-0.504182820497625-0.4999825037065629j))

# %% [markdown]
# In python we do not have a package that calculate the spherical hankel functions of the first kind, so parting from the hankel function we can write them
# \begin{equation}
#     h_n^{(1)}(z) = \sqrt{ \frac{\pi}{2z}}H_{n+1/2}^{(1)}(z)
# \end{equation}

# %%
def E_SCATnm(n, a_n, b_n, k, r, theta, phi):
    kr = k*r

    hn = np.sqrt(np.pi/(2*kr))*hankel1(n+1/2,kr)
    hn1 = np.sqrt(np.pi/(2*kr))*hankel1(n+1/2+1,kr)
    Pn1 = lpmv(1,n+1,np.cos(theta))
    Pn = lpmv(1,n,np.cos(theta))

    Gn = 1j**(n) 
    prefac = -Gn/(n*(n+1)) * (2*n+1)*1j

    term_r = -a_n/kr * hn  *Pn*n*(n+1)*np.cos(phi)

    term_the = (-a_n/kr* ( (n+1)*hn - kr*hn1 )* (n*Pn1-(n+1)*np.cos(theta)*Pn)/np.sin(theta) -1j* b_n * hn *Pn/np.sin(theta))*np.cos(phi)
    
    term_phi = (a_n/kr* ( (n+1)*hn - kr*hn1 )* Pn/np.sin(theta) +1j* b_n * hn *(n*Pn1-(n+1)*np.cos(theta)*Pn)/np.sin(theta))* np.sin(phi)
        
    return prefac*np.array([ term_r, term_the ,term_phi ])

# %% [markdown]
# **Comparing our code result with the giving by $\textit{MiePy}$**

# %%
# Constants
N = 200
wavelength = 0.65
radius = 1
k = 2 * np.pi / wavelength
x_value = k * radius
M = 1.33/1
phi = 0
theta = np.linspace(-np.pi,np.pi,300)
r = 1e4

E0_inc = np.array([np.sin(theta)*np.cos(phi)*np.exp(1j*k*r*np.cos(theta)) ,
                  np.cos(theta)*np.cos(phi)*np.exp(1j*k*r*np.cos(theta))  ,
                  -np.sin(phi)*np.ones(len(theta))*np.exp(1j*k*r*np.cos(theta))  ])  # Initialize the electric field array
E0_sca = 0

for i in range(1,N):
    a_n, b_n = MieCoef(x_value, M, i) 
    
    E0_sca += E_SCATnm(i, a_n, b_n, k, r, theta, phi) 

phi = np.pi/2  
E01_sca = 0

for i in range(1,N):
    a_n, b_n = MieCoef(x_value, M, i) 
    
    E01_sca += E_SCATnm(i, a_n, b_n, k, r, theta, phi)

# %%
import miepython

mu = np.cos(theta)
M2= M

Ipar, Iper = miepython.ez_intensities(M, 2*radius, wavelength, mu)

# %%
E = E0_sca
U =  abs(E[0])**2 + abs(E[1])**2+abs(E[2])**2

fig,ax=plt.subplots(1,2,figsize=(10,5))
ax[0].plot(theta*180/np.pi, U/max(U),'o',label='Simulated')
ax[0].plot(theta*180/np.pi,Ipar/max(Ipar),'--',label='MiePython')
ax[0].legend()

ax[0].set_yscale('log')
ax[0].set_xlabel('Angle (°)')
ax[0].set_ylabel('Normalized Intensity')
ax[0].set_title('(A)', fontname='Times New Roman',fontsize=45)

E = E01_sca
U =  abs(E[0])**2 + abs(E[1])**2+abs(E[2])**2

ax[1].plot(theta*180/np.pi, U/max(U),'o',label='Simulated')
ax[1].plot(theta*180/np.pi,Iper/max(Iper),'--',label='MiePython')
ax[1].legend()

ax[1].set_yscale('log')
ax[1].set_xlabel('Angle (°)')
ax[1].set_ylabel('Normalized Intensity')
ax[1].set_title('(B)', fontname='Times New Roman',fontsize=45)

plt.tight_layout()
plt.savefig('ComparaMiePython.png',dpi=300)

# %% [markdown]
# # Circle Image
#
# To make an image such as the circle shown using Rayleigh-Sommerfeld formulation we should change the coordiantes to cartesian, it can be easily done by applying
#
# \begin{align}
# \hat{r} &= \cos\phi\sin\theta\hat{x}+\sin\phi\sin\theta\hat{y}+\cos\theta\hat{z} \\
# \hat{\phi} &= -\sin\phi\hat{x} + \cos\phi\hat{y} \\
# \hat{\theta} &= \cos\phi\cos\theta\hat{x} + \sin\phi\cos\theta\hat{y} -\sin\theta\hat{z}
# \end{align}

# %%
def E1_SCATnm(n, a_n, b_n, k, x, y, z):
    r = np.sqrt(x**2 + y**2 + z**2)
    phi = np.sign(y) * np.arccos(x/np.sqrt(x**2+y**2))
    theta = np.arccos(z / r)

    kr = k * r
    hn = np.sqrt(np.pi / (2 * kr)) * hankel1(n + 1 / 2, kr)
    hn1 = np.sqrt(np.pi / (2 * kr)) * hankel1(n + 1 / 2 + 1, kr)
    Pn1 = lpmv(1, n + 1, np.cos(theta))
    Pn = lpmv(1, n, np.cos(theta))

    dP = (n * Pn1 - (n + 1) * np.cos(theta) * Pn) / np.sin(theta)
    P = Pn / np.sin(theta)

    # Replace zero values of dP and P at theta = 0 with -1/2*n*(n+1)

    zero_theta_indices = (np.where(abs(theta) < 10**(-10))[0])
    dP[zero_theta_indices] = -0.5 * n * (n + 1)
    P[zero_theta_indices] = -0.5 * n * (n + 1)

    zero_theta_indices = (np.isnan(phi))
    phi[zero_theta_indices] = 0
    
    Gn = 1j**n
    prefac = -Gn / (n * (n + 1)) * (2 * n + 1) * 1j

    term_r = -a_n / kr * hn * Pn * n * (n + 1) * np.cos(phi)
    term_the = (-a_n / kr * ((n + 1) * hn - kr * hn1) * dP - 1j * b_n * hn * P) * np.cos(phi)
    term_phi = (a_n / kr * ((n + 1) * hn - kr * hn1) * P + 1j * b_n * hn * dP) * np.sin(phi)

    return prefac * (np.array([term_r * np.cos(phi) * np.sin(theta), term_r * np.sin(theta) * np.sin(phi), term_r * np.cos(theta)]) +
                     np.array([term_the * np.cos(phi) * np.cos(theta), term_the * np.cos(theta) * np.sin(phi), -term_the * np.sin(theta)]) +
                     np.array([-term_phi * np.sin(phi), term_phi * np.cos(phi), np.zeros_like(r)]))

# %% [markdown]
# **Exemplo simples**

# %% [markdown]
# Para esfera menor

# %%
# Constants
N = 150
wavelength = 0.632
radius = 1
k = 2 * np.pi / wavelength
x_value = k * radius

y = 0
x = np.linspace(-2*radius,2*radius,300)

z = np.linspace(radius,100*radius,300)
x,z=np.meshgrid(x,z)

E11_sca = 0  # Initialize the electric field array
for i in range(1,N):
    #a_nm, b_nm = MieCoefCond(x_value, i)    
    a_n,b_n = MieCoefCond2(x_value, i, k)

    # Calculate the scattered electric field for both m=1 and m=-1
    E11_sca += E1_SCATnm(i, a_n, b_n, k, x, y, z)


print(E11_sca)
# Out:
# [[[ 6.73133968e-02+1.03601677e-01j  7.59910235e-02+9.80437595e-02j
#     8.41439375e-02+9.17851424e-02j ...  8.41439375e-02+9.17851424e-02j
#     7.59910235e-02+9.80437595e-02j  6.73133968e-02+1.03601677e-01j]
#   [-1.00490580e-01-4.79515262e-02j -1.03883575e-01-4.01582531e-02j
#    -1.06615171e-01-3.21543508e-02j ... -1.06615171e-01-3.21543508e-02j
#    -1.03883575e-01-4.01582531e-02j -1.00490580e-01-4.79515262e-02j]
#   [ 9.21492340e-02-1.60016198e-02j  8.93780415e-02-2.25210483e-02j
#     8.60927639e-02-2.86449502e-02j ...  8.60927639e-02-2.86449502e-02j
#     8.93780415e-02-2.25210483e-02j  9.21492340e-02-1.60016198e-02j]
#   ...
#   [-5.04067576e-02+1.19277616e-02j -5.03779562e-02+1.20648828e-02j
#    -5.03489791e-02+1.22010162e-02j ... -5.03489791e-02+1.22010162e-02j
#    -5.03779562e-02+1.20648828e-02j -5.04067576e-02+1.19277616e-02j]
#   [ 5.14507282e-02-4.27880625e-03j  5.14426970e-02-4.41775660e-03j
#     5.14343486e-02-4.55576265e-03j ...  5.14343486e-02-4.55576265e-03j
# ...

# %%
import matplotlib.pyplot as plt
x = np.linspace(-2*radius,2*radius,300)

z = np.linspace(radius,100*radius,300)
x,z=np.meshgrid(x,z)

E11_inc = np.array([np.exp(1j*k*z),
                   np.ones(300**2).reshape(300,300)*0,
                   0*np.ones(300**2).reshape(300,300) ])
E11 = E11_inc+E11_sca
U1 = abs(E11[0])**2 + np.abs(E11[1])**2 + np.abs(E11[2])**2

im=plt.imshow((U1).T,cmap='gray')
cbar = plt.colorbar(im)
cbar.set_label('Intensity', rotation=90, labelpad=-50)

plt.yticks([])
plt.xticks([])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 7
#       4 z = np.linspace(radius,100*radius,300)
#       5 x,z=np.meshgrid(x,z)
# ----> 7 E11_inc = np.array([np.exp(1j*k*Z),
#       8                    np.ones(301**2).reshape(301,301)*0,
#       9                    0*np.ones(301**2).reshape(301,301) ])
#      10 E11 = E11_inc+E11_sca
#      11 U1 = abs(E11[0])**2 + np.abs(E11[1])**2 + np.abs(E11[2])**2
#
# NameError: name 'Z' is not defined

# %% [markdown]
# **Fazer comparação no raio**

# %%
# Constants
N = 1400
wavelength = 0.632
radius = 100
k = 2 * np.pi / wavelength
x_value = k * radius

y = 0
x = 0

z = np.linspace(radius,100*radius,300)


E0_sca,E1_sca,E2_sca,E3_sca,E4_sca = 0,0,0,0,0

for i in range(1,N):
    
    a_n,b_n = MieCoefCond2(x_value, i, k)

    
    # Calculate the scattered electric field for both m=1 and m=-1
    if i <100:
        E0_sca += E1_SCATnm(i, a_n, b_n, k, x, y, z)
        #print(1)
    if i< 500:
        E1_sca += E1_SCATnm(i, a_n, b_n, k, x, y, z) 
        #print(2)
    if i <800:
        E2_sca += E1_SCATnm(i, a_n, b_n, k, x, y, z) 
        #print(3)
    if i <1100:
        E3_sca += E1_SCATnm(i, a_n, b_n, k, x, y, z)
        #print(4)
    E4_sca += E1_SCATnm(i, 1, a_n, b_n, k, x, y, z)

# %%
import matplotlib.pyplot as plt

fig,ax = plt.subplots(1,2,figsize = (10,5))

ax[0].plot(z , abs(-E0_sca[0]+np.exp(1j*k*z))**2+abs(E0_sca[1])**2+abs(E0_sca[2])**2, '-',label = 'n = 100')
ax[0].plot(z , abs(-E1_sca[0]+np.exp(1j*k*z))**2+abs(E1_sca[1])**2+abs(E1_sca[2])**2, '-',label = 'n = 500')
ax[0].plot(z , abs(-E2_sca[0]+np.exp(1j*k*z))**2+abs(E2_sca[1])**2+abs(E2_sca[2])**2, 'v',label = 'n = 800')
ax[0].plot(z , abs(-E3_sca[0]+np.exp(1j*k*z))**2+abs(E3_sca[1])**2+abs(E3_sca[2])**2, 'o',label = 'n = 1100')
ax[0].plot(z , abs(-E4_sca[0]+np.exp(1j*k*z))**2+abs(E4_sca[1])**2+abs(E4_sca[2])**2, '-',label = 'n = 1400')

#ax[0].set_yscale('log')
ax[0].legend()

ax[0].set_ylabel('Intensity (u.a.)')
ax[0].set_xlabel(' z (um)')
ax[0].set_title('(A)',fontname = 'Times New Roman', fontsize = 45)


ax[1].plot(z , abs(-E0_sca[0]+np.exp(1j*k*z))**2+abs(E0_sca[1])**2+abs(E0_sca[2])**2, '-',label = 'n = 100')
ax[1].plot(z , abs(-E1_sca[0]+np.exp(1j*k*z))**2+abs(E1_sca[1])**2+abs(E1_sca[2])**2, '-',label = 'n = 500')
ax[1].plot(z , abs(-E2_sca[0]+np.exp(1j*k*z))**2+abs(E2_sca[1])**2+abs(E2_sca[2])**2, 'v',label = 'n = 800')
ax[1].plot(z , abs(-E3_sca[0]+np.exp(1j*k*z))**2+abs(E3_sca[1])**2+abs(E3_sca[2])**2, 'o',label = 'n = 1100')
ax[1].plot(z , abs(-E4_sca[0]+np.exp(1j*k*z))**2+abs(E4_sca[1])**2+abs(E4_sca[2])**2, '-',label = 'n = 1400')

#ax[1].plot(z,z**2/(z**2+100**2))
#ax[1].set_yscale('log')
ax[1].set_xlim(0,1000)
ax[1].set_ylabel('Intensity (u.a.)')
ax[1].set_xlabel('  z  (um)')
ax[1].set_title('(B)',fontname = 'Times New Roman', fontsize = 45)
# Out:
# Text(0.5, 1.0, '(B)')

# %% [markdown]
# **IMAGE**

# %%
# Constants
N = 1000
wavelength = 0.632
radius = 100
k = 2 * np.pi / wavelength
x_value = k * radius
M = 1.4482/1#1 / 1.4482
#y=0
x= np.linspace(0.0001,120,600)
x,y = np.meshgrid(x,x)

z = 1000

EE_sca = 0  # Initialize the electric field array
#E_inc = np.array([np.ones(len(x))*0,np.ones(len(x))*0,0*np.ones(len(x)) ])

for i in range(1,N):
    a_nm, b_nm = MieCoefCond2(x_value, i,k)
    
    # Calculate the scattered electric field for both m=1 and m=-1
    EE_sca = EE_sca+ E1_SCATnm(i, a_nm, b_nm, k,  x, y, z) 

print(EE_sca)
# Out:
# [[[ 3.93111617e-01-1.33217007e-01j  3.89117548e-01-1.43492391e-01j
#     3.77293731e-01-1.73980347e-01j ...  6.83960490e-02+1.53058977e-01j
#     5.32560223e-02+1.58141531e-01j  3.71460971e-02+1.58907214e-01j]
#   [ 3.92893478e-01-1.39859753e-01j  3.88911413e-01-1.50093433e-01j
#     3.77123176e-01-1.80457245e-01j ...  6.83843301e-02+1.53064942e-01j
#     5.32428040e-02+1.58144086e-01j  3.71328634e-02+1.58906036e-01j]
#   [ 3.92232548e-01-1.59593655e-01j  3.88286273e-01-1.69703039e-01j
#     3.76604125e-01-1.99696859e-01j ...  6.83491860e-02+1.53082809e-01j
#     5.32031715e-02+1.58151730e-01j  3.70931928e-02+1.58902487e-01j]
#   ...
#   [ 1.00219796e-01+1.75983424e-01j  1.00212023e-01+1.75984154e-01j
#     1.00188722e-01+1.75986339e-01j ... -1.43314777e-02-3.94951174e-02j
#    -1.10583738e-02-3.88195124e-02j -8.45539195e-03-3.82007232e-02j]
#   [ 9.14672987e-02+1.76564796e-01j  9.14602359e-02+1.76564981e-01j
#     9.14390651e-02+1.76565537e-01j ... -1.11795224e-02-3.88754303e-02j
# ...

# %%
print(z//radius)
# Out:
# 10

# %%
import matplotlib.pyplot as plt
n=600
EE_inc = np.array([np.ones(n*n).reshape(n,n)*np.exp(1j*k*z), 
                   0*np.ones(n*n).reshape(n,n),
                   0*np.ones(n*n).reshape(n,n)])

EE = EE_inc+EE_sca
UU = np.abs(EE[0])**2 + np.abs(EE[1])**2 + np.abs(EE[2])**2

img = plt.imshow(UU,cmap='gray',vmin=0.1,vmax=1.3)
plt.yticks([])
plt.xticks([])
cbar = plt.colorbar(img)
cbar.set_label("Intensity")  # Adjust the distance and position
cbar.ax.yaxis.set_label_position("left")  # Ensure the label is on the right side


#plt.savefig('Mie.svg',dpi=300)

# %%
# Mirror the data along both axes
UU_full = np.block([
    [np.flip(np.flip(UU, axis=0), axis=1), np.flip(UU, axis=0)],
    [np.flip(UU, axis=1), UU]
])

fig = plt.subplots(figsize=(9,7))
# Plot the full figure
img = plt.imshow(UU_full, cmap='gray',aspect='auto', vmin=0.1, vmax=1.4)
plt.yticks([])
plt.xticks([])


cbar = plt.colorbar(img)
cbar.set_label("Intensity")  # Adjust the distance and position
cbar.ax.yaxis.set_label_position("left")  # Ensure the label is on the right side
# Save the figure
plt.tight_layout()
plt.savefig('Mie.pdf', dpi=300)
plt.show()

# %% [markdown]
# # Otimizar
